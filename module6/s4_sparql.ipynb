# %% [markdown]
# # Bases de connaissance : interroger Wikidata à l'aide de requêtes SPARQL

# %% [markdown]
# ## Imports

# %%
from datetime import datetime as dt
from SPARQLWrapper import SPARQLWrapper, JSON

# %% [markdown]
# ## Obtenir la liste des politiciens belges

# %%
# Retrieve results from SPARQL
endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
sparql = SPARQLWrapper(endpoint)

# P27 = country of citizenship 
# Q31 = Belgium
# P106 = Opccupation
# Q82955 = Politician
# P569 = date of birth
# P570 = date of death
statement = """
SELECT DISTINCT ?person ?personLabel ?dateBirth ?dateDeath WHERE {
    # ?person wdt:P27 wd:Q31 .
    # ?person wdt:P106 wd:Q82955 .
    # ?person wdt:P569 ?dateBirth .
    OPTIONAL {?person wdt:P570 ?dateDeath .}
    SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
ORDER BY ?personLabel
"""

sparql.setQuery(statement)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

rows = results['results']['bindings']
print(f"\n{len(rows)} Belgian politicians found\n")
print(rows[:10])
# Out:
# 8125 Belgian politicians found
#
# [{'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q12724173'}, 'personLabel': {'type': 'literal', 'value': 'Q12724173'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1931-11-11T00:00:00Z'}, 'dateDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2019-04-24T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q131716615'}, 'personLabel': {'type': 'literal', 'value': 'Q131716615'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1993-03-02T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q131741872'}, 'personLabel': {'type': 'literal', 'value': 'Q131741872'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1982-12-30T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q131745023'}, 'personLabel': {'type': 'literal', 'value': 'Q131745023'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1911-01-01T00:00:00Z'}, 'dateDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1998-01-01T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132128244'}, 'personLabel': {'type': 'literal', 'value': 'Q132128244'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1952-02-29T00:00:00Z'}, 'dateDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '2011-01-30T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132184868'}, 'personLabel': {'type': 'literal', 'value': 'Q132184868'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1971-02-27T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132672668'}, 'personLabel': {'type': 'literal', 'value': 'Q132672668'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1981-04-29T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132797221'}, 'personLabel': {'type': 'literal', 'value': 'Q132797221'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1926-10-23T00:00:00Z'}, 'dateDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1987-03-15T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q133539242'}, 'personLabel': {'type': 'literal', 'value': 'Q133539242'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1900-10-10T00:00:00Z'}}, {'person': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q134272403'}, 'personLabel': {'type': 'literal', 'value': 'Q134272403'}, 'dateBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1983-01-01T00:00:00Z'}}]

# %% [markdown]
# ## Filtrer pour n'afficher que les noms contenant "Alphonse"

# %%
name_filter = 'Alphonse'
max_results = 10

date_format = "%Y-%m-%dT%H:%M:%SZ"
filtered_rows = [row for row in rows if name_filter in row['personLabel']['value']]
print(f"Displaying the first {max_results}:\n")
for row in filtered_rows[:max_results]:
    try:
        birth_date = dt.strptime(row['dateBirth']['value'], date_format)
        birth_year = birth_date.year
    except ValueError:
        birth_year = "????"
    try:
        death_date = dt.strptime(row['dateDeath']['value'], date_format)
        death_year = death_date.year
    except ValueError: # unknown death date
        death_year = "????"
    except KeyError: # still alive
        death_year = ""
    print(f"{row['personLabel']['value']} ({birth_year}-{death_year})")
# Out:
# Displaying the first 10:
#
# Adolphe-Alphonse Goupy de Beauvolers (1796-1869)
# Alphonse Bonenfant (1908-1983)
# Alphonse Bosch (1886-1944)
# Alphonse Brenez (1862-1933)
# Alphonse Briart (1864-1936)
# Alphonse Carpentier (1869-1934)
# Alphonse Casse (1846-1923)
# Alphonse Clignez (1886-1965)
# Alphonse Collet (1905-1971)
# Alphonse De Haene (1863-1939)

# %% [markdown]
# ## Pour en savoir plus

# %% [markdown]
# - [Le projet Wikidata](https://www.wikidata.org/wiki/Wikidata:Main_Page)
# - [Aide à la construction de requêtes](https://query.wikidata.org/)
